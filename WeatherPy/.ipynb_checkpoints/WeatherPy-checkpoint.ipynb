# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city + "&appid=" + weather_api_key + "&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bukene
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | bilibino
# Processing Record 4 of Set 1 | puerto baquerizo moreno
# Processing Record 5 of Set 1 | mirnyy
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | atafu village
# Processing Record 10 of Set 1 | pathein
# Processing Record 11 of Set 1 | devils lake
# Processing Record 12 of Set 1 | bardai
# Processing Record 13 of Set 1 | dudinka
# Processing Record 14 of Set 1 | togur
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | puerto natales
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | khorixas
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | orahovac
# Processing Record 23 of Set 1 | saint-pierre
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | souda
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | mirriah
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | fale old settlement
# Processing Record 33 of Set 1 | ceeldheer
# Processing Record 34 of Set 1 | grytviken
# Processing Record 35 of Set 1 | tuxpan
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | muynoq
# Processing Record 38 of Set 1 | iskateley
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | luganville
# Processing Record 41 of Set 1 | minokamo
# Processing Record 42 of Set 1 | mejit
# Processing Record 43 of Set 1 | plettenberg bay
# Processing Record 44 of Set 1 | whitehorse
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | fort bragg
# Processing Record 47 of Set 1 | nkhata bay
# Processing Record 48 of Set 1 | vilyuchinsk
# Processing Record 49 of Set 1 | iturama
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 0 of Set 2 | cafayate
# Processing Record 1 of Set 2 | kudahuvadhoo
# Processing Record 2 of Set 2 | papatowai
# Processing Record 3 of Set 2 | anadyr
# Processing Record 4 of Set 2 | kaitong
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | stanley
# Processing Record 7 of Set 2 | rye
# Processing Record 8 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 9 of Set 2 | bikenibeu village
# Processing Record 10 of Set 2 | malango
# Processing Record 11 of Set 2 | constitucion
# Processing Record 12 of Set 2 | weno
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | coahuayana de hidalgo
# Processing Record 15 of Set 2 | turpan
# Processing Record 16 of Set 2 | inhambane
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | las tablas
# Processing Record 19 of Set 2 | blackmans bay
# Processing Record 20 of Set 2 | polyarnyy
# Processing Record 21 of Set 2 | olyokminsk
# Processing Record 22 of Set 2 | nelson bay
# Processing Record 23 of Set 2 | howrah
# Processing Record 24 of Set 2 | chiredzi
# Processing Record 25 of Set 2 | st. john's
# Processing Record 26 of Set 2 | tremp
# Processing Record 27 of Set 2 | severo-yeniseyskiy
# Processing Record 28 of Set 2 | timimoun
# Processing Record 29 of Set 2 | wenceslau braz
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | aykhal
# Processing Record 32 of Set 2 | wailua homesteads
# Processing Record 33 of Set 2 | semey
# Processing Record 34 of Set 2 | utrik
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | port mathurin
# Processing Record 37 of Set 2 | maturin
# Processing Record 38 of Set 2 | badger
# Processing Record 39 of Set 2 | queenstown
# Processing Record 40 of Set 2 | baishishan
# Processing Record 41 of Set 2 | naze
# Processing Record 42 of Set 2 | kapuskasing
# Processing Record 43 of Set 2 | akrehamn
# Processing Record 44 of Set 2 | demre
# Processing Record 45 of Set 2 | espargos
# City not found. Skipping...
# Processing Record 46 of Set 2 | teguise
# Processing Record 47 of Set 2 | fisterra
# Processing Record 48 of Set 2 | gobabis
# Processing Record 49 of Set 2 | tamanrasset
# Processing Record 0 of Set 3 | waycross
# Processing Record 1 of Set 3 | illizi
# Processing Record 2 of Set 3 | selfoss
# Processing Record 3 of Set 3 | annau
# Processing Record 4 of Set 3 | constantia
# Processing Record 5 of Set 3 | olonkinbyen
# Processing Record 6 of Set 3 | dryden
# Processing Record 7 of Set 3 | imphal
# Processing Record 8 of Set 3 | mount pearl
# Processing Record 9 of Set 3 | ban dung
# Processing Record 10 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 11 of Set 3 | luis correia
# Processing Record 12 of Set 3 | lerwick
# Processing Record 13 of Set 3 | afaahiti
# Processing Record 14 of Set 3 | fort william
# Processing Record 15 of Set 3 | portland
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | novhorod-sivers'kyy
# Processing Record 19 of Set 3 | sinabang
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | bamboo flat
# Processing Record 22 of Set 3 | caister-on-sea
# Processing Record 23 of Set 3 | kingston
# Processing Record 24 of Set 3 | medvedevo
# Processing Record 25 of Set 3 | magadan
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | makokou
# Processing Record 28 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 29 of Set 3 | karaton
# Processing Record 30 of Set 3 | bethel
# Processing Record 31 of Set 3 | abalak
# Processing Record 32 of Set 3 | kabompo
# Processing Record 33 of Set 3 | lebu
# Processing Record 34 of Set 3 | bara
# Processing Record 35 of Set 3 | kerikeri
# Processing Record 36 of Set 3 | ocean city
# Processing Record 37 of Set 3 | parry sound
# Processing Record 38 of Set 3 | inarajan village
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | ta`u
# Processing Record 41 of Set 3 | tabou
# Processing Record 42 of Set 3 | hafnarfjordur
# Processing Record 43 of Set 3 | udachny
# Processing Record 44 of Set 3 | ternate
# Processing Record 45 of Set 3 | cururupu
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | uturoa
# Processing Record 48 of Set 3 | flying fish cove
# Processing Record 49 of Set 3 | melekeok village
# Processing Record 0 of Set 4 | luderitz
# Processing Record 1 of Set 4 | karratha
# Processing Record 2 of Set 4 | gua musang
# Processing Record 3 of Set 4 | aasiaat
# Processing Record 4 of Set 4 | sao felix do xingu
# Processing Record 5 of Set 4 | saipan
# Processing Record 6 of Set 4 | hadibu
# Processing Record 7 of Set 4 | ulladulla
# Processing Record 8 of Set 4 | al bawiti
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | susuman
# Processing Record 11 of Set 4 | gadzhiyevo
# Processing Record 12 of Set 4 | heinola
# Processing Record 13 of Set 4 | fada
# Processing Record 14 of Set 4 | acarau
# Processing Record 15 of Set 4 | ketchikan
# Processing Record 16 of Set 4 | stadthagen
# Processing Record 17 of Set 4 | west island
# Processing Record 18 of Set 4 | sodo
# Processing Record 19 of Set 4 | planaltina
# Processing Record 20 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 21 of Set 4 | brisas de zicatela
# Processing Record 22 of Set 4 | tolanaro
# Processing Record 23 of Set 4 | rikaze
# Processing Record 24 of Set 4 | okha
# Processing Record 25 of Set 4 | canguaretama
# Processing Record 26 of Set 4 | mandalay
# Processing Record 27 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 28 of Set 4 | kununurra
# Processing Record 29 of Set 4 | khandyga
# Processing Record 30 of Set 4 | prince rupert
# Processing Record 31 of Set 4 | inaruwa
# Processing Record 32 of Set 4 | nuku'alofa
# Processing Record 33 of Set 4 | tomatlan
# Processing Record 34 of Set 4 | persembe
# Processing Record 35 of Set 4 | la libertad
# Processing Record 36 of Set 4 | rantepao
# Processing Record 37 of Set 4 | kincardine
# Processing Record 38 of Set 4 | hamilton
# Processing Record 39 of Set 4 | nar'yan-mar
# Processing Record 40 of Set 4 | port saint john's
# Processing Record 41 of Set 4 | san juan
# Processing Record 42 of Set 4 | santa fe
# Processing Record 43 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 44 of Set 4 | margaret river
# Processing Record 45 of Set 4 | saratamata
# City not found. Skipping...
# Processing Record 46 of Set 4 | ar rutbah
# Processing Record 47 of Set 4 | ust-nera
# Processing Record 48 of Set 4 | isafjordur
# Processing Record 49 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 0 of Set 5 | conception bay south
# Processing Record 1 of Set 5 | keflavik
# Processing Record 2 of Set 5 | ha giang
# Processing Record 3 of Set 5 | colonia
# Processing Record 4 of Set 5 | lycksele
# Processing Record 5 of Set 5 | tokar
# Processing Record 6 of Set 5 | doctor alberto oviedo mota
# Processing Record 7 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 5 | jamui
# Processing Record 9 of Set 5 | ola
# Processing Record 10 of Set 5 | florencia
# Processing Record 11 of Set 5 | kuppam
# Processing Record 12 of Set 5 | sheboygan
# Processing Record 13 of Set 5 | bireun
# Processing Record 14 of Set 5 | mumbwa
# Processing Record 15 of Set 5 | tapes
# Processing Record 16 of Set 5 | palikir - national government center
# Processing Record 17 of Set 5 | cidade velha
# Processing Record 18 of Set 5 | serang
# Processing Record 19 of Set 5 | afif
# Processing Record 20 of Set 5 | kaoma
# Processing Record 21 of Set 5 | hailar
# Processing Record 22 of Set 5 | rawala kot
# Processing Record 23 of Set 5 | san juan bautista
# Processing Record 24 of Set 5 | remire-montjoly
# Processing Record 25 of Set 5 | angarsk
# Processing Record 26 of Set 5 | minas de marcona
# Processing Record 27 of Set 5 | tutoia
# Processing Record 28 of Set 5 | beacon square
# Processing Record 29 of Set 5 | qaqortoq
# Processing Record 30 of Set 5 | saint-paul
# Processing Record 31 of Set 5 | kapa'a
# Processing Record 32 of Set 5 | cockburn town
# Processing Record 33 of Set 5 | kuala belait
# Processing Record 34 of Set 5 | bakanas
# Processing Record 35 of Set 5 | lanxi
# Processing Record 36 of Set 5 | al 'alamayn
# City not found. Skipping...
# Processing Record 37 of Set 5 | dongcun
# Processing Record 38 of Set 5 | chonchi
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | bargarh
# Processing Record 41 of Set 5 | chibougamau
# Processing Record 42 of Set 5 | chernomorskoye
# Processing Record 43 of Set 5 | scottburgh
# Processing Record 44 of Set 5 | vadso
# Processing Record 45 of Set 5 | harper
# Processing Record 46 of Set 5 | cole harbour
# Processing Record 47 of Set 5 | samamea
# City not found. Skipping...
# Processing Record 48 of Set 5 | invercargill
# Processing Record 49 of Set 5 | kavaratti
# Processing Record 0 of Set 6 | port lincoln
# Processing Record 1 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 2 of Set 6 | kolonia
# Processing Record 3 of Set 6 | puerto colombia
# Processing Record 4 of Set 6 | mahibadhoo
# Processing Record 5 of Set 6 | fernie
# Processing Record 6 of Set 6 | antofagasta
# Processing Record 7 of Set 6 | hawaiian paradise park
# Processing Record 8 of Set 6 | belmonte
# Processing Record 9 of Set 6 | pangody
# Processing Record 10 of Set 6 | sur
# Processing Record 11 of Set 6 | sibiti
# Processing Record 12 of Set 6 | sinop
# Processing Record 13 of Set 6 | malkapur
# Processing Record 14 of Set 6 | arkhangel'sk
# Processing Record 15 of Set 6 | akureyri
# Processing Record 16 of Set 6 | kayangel
# Processing Record 17 of Set 6 | lorengau
# Processing Record 18 of Set 6 | vokhtoga
# Processing Record 19 of Set 6 | yuzhno-kurilsk
# Processing Record 20 of Set 6 | bam
# Processing Record 21 of Set 6 | college
# Processing Record 22 of Set 6 | alice springs
# Processing Record 23 of Set 6 | karbala
# Processing Record 24 of Set 6 | pacific grove
# Processing Record 25 of Set 6 | ciechanow
# Processing Record 26 of Set 6 | port blair
# Processing Record 27 of Set 6 | punta arenas
# Processing Record 28 of Set 6 | findlay
# Processing Record 29 of Set 6 | lensk
# Processing Record 30 of Set 6 | hasparren
# Processing Record 31 of Set 6 | gallatin
# Processing Record 32 of Set 6 | spring creek
# Processing Record 33 of Set 6 | piti village
# Processing Record 34 of Set 6 | ermelo
# Processing Record 35 of Set 6 | corpus christi
# Processing Record 36 of Set 6 | novyy urgal
# Processing Record 37 of Set 6 | aginskoye
# Processing Record 38 of Set 6 | zuunmod
# Processing Record 39 of Set 6 | mawlamyinegyunn
# Processing Record 40 of Set 6 | nova sintra
# Processing Record 41 of Set 6 | mahriz
# Processing Record 42 of Set 6 | morant bay
# Processing Record 43 of Set 6 | sattahip
# Processing Record 44 of Set 6 | bagan serai
# Processing Record 45 of Set 6 | georgetown
# Processing Record 46 of Set 6 | tazacorte
# Processing Record 47 of Set 6 | stephenville
# Processing Record 48 of Set 6 | oguz
# Processing Record 49 of Set 6 | ascension
# Processing Record 0 of Set 7 | santiago de cao
# Processing Record 1 of Set 7 | kantunilkin
# Processing Record 2 of Set 7 | aban
# Processing Record 3 of Set 7 | mundri
# Processing Record 4 of Set 7 | al-`ula
# City not found. Skipping...
# Processing Record 5 of Set 7 | livny
# Processing Record 6 of Set 7 | nikolayevsk-on-amure
# Processing Record 7 of Set 7 | bahia blanca
# Processing Record 8 of Set 7 | kideksha
# Processing Record 9 of Set 7 | bel ombre
# Processing Record 10 of Set 7 | korla
# Processing Record 11 of Set 7 | vorgashor
# Processing Record 12 of Set 7 | stjordalshalsen
# Processing Record 13 of Set 7 | azul
# Processing Record 14 of Set 7 | argostolion
# Processing Record 15 of Set 7 | floro
# Processing Record 16 of Set 7 | amahai
# Processing Record 17 of Set 7 | rouissat
# Processing Record 18 of Set 7 | tonota
# Processing Record 19 of Set 7 | malaya purga
# Processing Record 20 of Set 7 | pitkyaranta
# Processing Record 21 of Set 7 | nguigmi
# Processing Record 22 of Set 7 | tazovsky
# Processing Record 23 of Set 7 | nuuk
# Processing Record 24 of Set 7 | mata-utu
# Processing Record 25 of Set 7 | lompoc
# Processing Record 26 of Set 7 | cancun
# Processing Record 27 of Set 7 | chui
# Processing Record 28 of Set 7 | qamdo
# Processing Record 29 of Set 7 | zhanaozen
# Processing Record 30 of Set 7 | san patricio
# Processing Record 31 of Set 7 | santa terezinha
# Processing Record 32 of Set 7 | happy valley-goose bay
# Processing Record 33 of Set 7 | manta
# Processing Record 34 of Set 7 | ulety
# Processing Record 35 of Set 7 | singkil
# Processing Record 36 of Set 7 | vernon
# Processing Record 37 of Set 7 | jianshui
# Processing Record 38 of Set 7 | ouadda
# Processing Record 39 of Set 7 | myanaung
# Processing Record 40 of Set 7 | enewetak
# Processing Record 41 of Set 7 | meulaboh
# Processing Record 42 of Set 7 | mawu
# Processing Record 43 of Set 7 | nosy varika
# Processing Record 44 of Set 7 | el porvenir
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | medina
# Processing Record 47 of Set 7 | pekin
# Processing Record 48 of Set 7 | isla mujeres
# Processing Record 49 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 0 of Set 8 | toliara
# Processing Record 1 of Set 8 | molalla
# Processing Record 2 of Set 8 | okhotsk
# Processing Record 3 of Set 8 | haiku-pauwela
# Processing Record 4 of Set 8 | greymouth
# Processing Record 5 of Set 8 | alaghsas
# Processing Record 6 of Set 8 | taksimo
# Processing Record 7 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 8 of Set 8 | pizarro
# Processing Record 9 of Set 8 | tralee
# Processing Record 10 of Set 8 | nova vicosa
# Processing Record 11 of Set 8 | deqen
# Processing Record 12 of Set 8 | le moule
# Processing Record 13 of Set 8 | antipino
# Processing Record 14 of Set 8 | mount gambier
# Processing Record 15 of Set 8 | klyuchi
# Processing Record 16 of Set 8 | sao jose da coroa grande
# Processing Record 17 of Set 8 | cam ranh
# Processing Record 18 of Set 8 | la foa
# Processing Record 19 of Set 8 | labytnangi
# Processing Record 20 of Set 8 | mandalgovi
# Processing Record 21 of Set 8 | oranjemund
# Processing Record 22 of Set 8 | belyy yar
# Processing Record 23 of Set 8 | sisimiut
# Processing Record 24 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 25 of Set 8 | penzance
# Processing Record 26 of Set 8 | mountain home
# Processing Record 27 of Set 8 | cabedelo
# Processing Record 28 of Set 8 | mitu
# Processing Record 29 of Set 8 | hafar al-batin
# Processing Record 30 of Set 8 | chuguyevka
# Processing Record 31 of Set 8 | shengli
# Processing Record 32 of Set 8 | naifaru
# Processing Record 33 of Set 8 | riversdale
# Processing Record 34 of Set 8 | boueni
# Processing Record 35 of Set 8 | palangkaraya
# Processing Record 36 of Set 8 | gamba
# Processing Record 37 of Set 8 | la passe
# Processing Record 38 of Set 8 | tumayr
# Processing Record 39 of Set 8 | ouesso
# Processing Record 40 of Set 8 | flin flon
# Processing Record 41 of Set 8 | san antonio de pale
# Processing Record 42 of Set 8 | yambio
# Processing Record 43 of Set 8 | revda
# Processing Record 44 of Set 8 | kotel'va
# Processing Record 45 of Set 8 | bangolo
# Processing Record 46 of Set 8 | ciudad nueva
# Processing Record 47 of Set 8 | antonio enes
# Processing Record 48 of Set 8 | pacol
# Processing Record 49 of Set 8 | melfort
# Processing Record 0 of Set 9 | nadym
# Processing Record 1 of Set 9 | weyburn
# Processing Record 2 of Set 9 | ak-suu
# Processing Record 3 of Set 9 | yeppoon
# Processing Record 4 of Set 9 | oamaru
# Processing Record 5 of Set 9 | hobyo
# Processing Record 6 of Set 9 | pauini
# Processing Record 7 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 8 of Set 9 | angaur state
# Processing Record 9 of Set 9 | lihue
# Processing Record 10 of Set 9 | hithadhoo
# Processing Record 11 of Set 9 | turbana
# Processing Record 12 of Set 9 | furstenfeld
# Processing Record 13 of Set 9 | zabol
# Processing Record 14 of Set 9 | kailua-kona
# Processing Record 15 of Set 9 | beasain
# Processing Record 16 of Set 9 | uyar
# Processing Record 17 of Set 9 | guroymak
# Processing Record 18 of Set 9 | wynyard
# Processing Record 19 of Set 9 | korhogo
# Processing Record 20 of Set 9 | evanston
# Processing Record 21 of Set 9 | sudak
# Processing Record 22 of Set 9 | medicine hat
# Processing Record 23 of Set 9 | charters towers
# Processing Record 24 of Set 9 | ancud
# Processing Record 25 of Set 9 | teykovo
# Processing Record 26 of Set 9 | lewiston orchards
# Processing Record 27 of Set 9 | yanykurgan
# Processing Record 28 of Set 9 | freetown
# Processing Record 29 of Set 9 | dubrovnik
# Processing Record 30 of Set 9 | rakops
# Processing Record 31 of Set 9 | ballina
# Processing Record 32 of Set 9 | jinghong
# Processing Record 33 of Set 9 | malvan
# Processing Record 34 of Set 9 | new norfolk
# Processing Record 35 of Set 9 | raudales malpaso
# City not found. Skipping...
# Processing Record 36 of Set 9 | bingerville
# Processing Record 37 of Set 9 | bushland beach
# City not found. Skipping...
# Processing Record 38 of Set 9 | mersing
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | broken hill
# Processing Record 41 of Set 9 | birao
# Processing Record 42 of Set 9 | aksu
# Processing Record 43 of Set 9 | la'ie
# Processing Record 44 of Set 9 | pachino
# Processing Record 45 of Set 9 | klaksvik
# Processing Record 46 of Set 9 | tofol
# Processing Record 47 of Set 9 | quellon
# Processing Record 48 of Set 9 | arno
# Processing Record 49 of Set 9 | novoorsk
# Processing Record 0 of Set 10 | jumla
# Processing Record 1 of Set 10 | thanh hoa
# Processing Record 2 of Set 10 | isle of lewis
# City not found. Skipping...
# Processing Record 3 of Set 10 | luang namtha
# Processing Record 4 of Set 10 | rio grande
# Processing Record 5 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 6 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 7 of Set 10 | genhe
# Processing Record 8 of Set 10 | cidreira
# Processing Record 9 of Set 10 | carutapera
# Processing Record 10 of Set 10 | vila velha
# Processing Record 11 of Set 10 | yartsevo
# Processing Record 12 of Set 10 | santa isabel
# Processing Record 13 of Set 10 | tabuk
# Processing Record 14 of Set 10 | bethanie
# Processing Record 15 of Set 10 | tourlaville
# Processing Record 16 of Set 10 | verkh-neyvinskiy
# Processing Record 17 of Set 10 | blanchard
# Processing Record 18 of Set 10 | tiffin
# Processing Record 19 of Set 10 | port hueneme
# Processing Record 20 of Set 10 | taoudenni
# Processing Record 21 of Set 10 | masuguru
# Processing Record 22 of Set 10 | mikhnevo
# Processing Record 23 of Set 10 | carnarvon
# Processing Record 24 of Set 10 | gisborne
# Processing Record 25 of Set 10 | motueka
# Processing Record 26 of Set 10 | dadonghai
# City not found. Skipping...
# Processing Record 27 of Set 10 | anyang-si
# Processing Record 28 of Set 10 | puerto aysen
# Processing Record 29 of Set 10 | hillsboro
# Processing Record 30 of Set 10 | canton
# Processing Record 31 of Set 10 | oodweyne
# Processing Record 32 of Set 10 | morsi
# Processing Record 33 of Set 10 | coari
# Processing Record 34 of Set 10 | naantali
# Processing Record 35 of Set 10 | cruzeiro do sul
# Processing Record 36 of Set 10 | popayan
# Processing Record 37 of Set 10 | san juan de miraflores
# Processing Record 38 of Set 10 | ambon
# Processing Record 39 of Set 10 | walvis bay
# Processing Record 40 of Set 10 | praia da vitoria
# Processing Record 41 of Set 10 | tateyama
# Processing Record 42 of Set 10 | kargasok
# Processing Record 43 of Set 10 | faya-largeau
# Processing Record 44 of Set 10 | villa gesell
# Processing Record 45 of Set 10 | kirksville
# Processing Record 46 of Set 10 | bom jesus
# Processing Record 47 of Set 10 | haparanda
# Processing Record 48 of Set 10 | fort stockton
# Processing Record 49 of Set 10 | zhangye
# Processing Record 0 of Set 11 | broome
# Processing Record 1 of Set 11 | crane
# Processing Record 2 of Set 11 | kotlas
# Processing Record 3 of Set 11 | muhos
# Processing Record 4 of Set 11 | navolato
# Processing Record 5 of Set 11 | lugovoy
# Processing Record 6 of Set 11 | rawson
# Processing Record 7 of Set 11 | undurkhaan
# Processing Record 8 of Set 11 | mudanjiang
# Processing Record 9 of Set 11 | tsiombe
# Processing Record 10 of Set 11 | abepura
# Processing Record 11 of Set 11 | kirakira
# Processing Record 12 of Set 11 | camana
# Processing Record 13 of Set 11 | ijuw
# City not found. Skipping...
# Processing Record 14 of Set 11 | yung shue wan
# Processing Record 15 of Set 11 | charles city
# Processing Record 16 of Set 11 | lata
# Processing Record 17 of Set 11 | gambiran satu
# Processing Record 18 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 11 | great falls
# Processing Record 20 of Set 11 | mugia
# Processing Record 21 of Set 11 | burabay
# Processing Record 22 of Set 11 | mermoz boabab
# Processing Record 23 of Set 11 | kota tinggi
# Processing Record 24 of Set 11 | kidal
# Processing Record 25 of Set 11 | panaba
# Processing Record 26 of Set 11 | mocimboa
# Processing Record 27 of Set 11 | yaounde
# Processing Record 28 of Set 11 | zaozersk
# Processing Record 29 of Set 11 | swakopmund
# Processing Record 30 of Set 11 | toyooka
# Processing Record 31 of Set 11 | hilo
# Processing Record 32 of Set 11 | siwa oasis
# Processing Record 33 of Set 11 | wakkanai
# Processing Record 34 of Set 11 | matsumoto
# Processing Record 35 of Set 11 | chizhou
# Processing Record 36 of Set 11 | salinopolis
# Processing Record 37 of Set 11 | trairi
# Processing Record 38 of Set 11 | mahina
# Processing Record 39 of Set 11 | raduzhny
# Processing Record 40 of Set 11 | levuka
# Processing Record 41 of Set 11 | majene
# Processing Record 42 of Set 11 | viana do castelo
# Processing Record 43 of Set 11 | otjiwarongo
# Processing Record 44 of Set 11 | ambalangoda
# Processing Record 45 of Set 11 | geraldton
# Processing Record 46 of Set 11 | linden
# Processing Record 47 of Set 11 | moose jaw
# Processing Record 48 of Set 11 | port hedland
# Processing Record 49 of Set 11 | solnechnyy
# Processing Record 0 of Set 12 | mandan
# Processing Record 1 of Set 12 | luwuk
# Processing Record 2 of Set 12 | bathsheba
# Processing Record 3 of Set 12 | qarqaraly
# Processing Record 4 of Set 12 | kansk
# Processing Record 5 of Set 12 | lautoka
# Processing Record 6 of Set 12 | kauran
# Processing Record 7 of Set 12 | bure
# Processing Record 8 of Set 12 | dawson creek
# Processing Record 9 of Set 12 | shimoda
# Processing Record 10 of Set 12 | san andros
# City not found. Skipping...
# Processing Record 11 of Set 12 | thinadhoo
# Processing Record 12 of Set 12 | iguape
# Processing Record 13 of Set 12 | berezovo
# Processing Record 14 of Set 12 | padang
# Processing Record 15 of Set 12 | champerico
# Processing Record 16 of Set 12 | sarangani
# Processing Record 17 of Set 12 | raychikhinsk
# Processing Record 18 of Set 12 | kalabo
# Processing Record 19 of Set 12 | rongelap
# Processing Record 20 of Set 12 | lake elsinore
# Processing Record 21 of Set 12 | sao mateus do sul
# Processing Record 22 of Set 12 | callao
# Processing Record 23 of Set 12 | noumea
# Processing Record 24 of Set 12 | roma
# Processing Record 25 of Set 12 | holualoa
# Processing Record 26 of Set 12 | banda aceh
# Processing Record 27 of Set 12 | kalininskaya
# Processing Record 28 of Set 12 | mohali
# Processing Record 29 of Set 12 | san diego de alejandria
# Processing Record 30 of Set 12 | jacksonville
# Processing Record 31 of Set 12 | siofok
# Processing Record 32 of Set 12 | valparaiso
# Processing Record 33 of Set 12 | alofi
# Processing Record 34 of Set 12 | corner brook
# Processing Record 35 of Set 12 | calingasta
# Processing Record 36 of Set 12 | brookings
# Processing Record 37 of Set 12 | soure
# Processing Record 38 of Set 12 | aioun
# Processing Record 39 of Set 12 | viiala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

#Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head(20)
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# 0                        bukene  -4.2333   32.8833     70.52        69
# 1             port-aux-francais -49.3500   70.2167     34.74       100
# 2                      bilibino  68.0546  166.4372     19.96        86
# 3       puerto baquerizo moreno  -0.9000  -89.6000     75.33        80
# 4                        mirnyy  62.5353  113.9611     41.67        96
# 5                          tura  25.5198   90.2201     82.45        69
# 6   edinburgh of the seven seas -37.0676  -12.3116     56.44        83
# 7                        avarua -21.2078 -159.7750     75.25        73
# 8                 atafu village  -8.5421 -172.5159     82.53        75
# 9                       pathein  16.7833   94.7333     84.43        73
# 10                  devils lake  48.1128  -98.8651     44.94        83
# 11                       bardai  11.6500    7.2333     72.39        58
# 12                      dudinka  69.4058   86.1778     34.68        93
# 13                        togur  58.3631   82.8265     39.15        87
# 14                       namibe -15.1961   12.1522     67.14        87
# 15               puerto natales -51.7236  -72.4875     38.43        93
# 16                      iqaluit  63.7506  -68.5145     29.93        86
# 17                  port alfred -33.5906   26.8910     64.18        97
# 18                     waitangi -43.9535 -176.5597     53.82        77
# 19                     khorixas -20.3667   14.9667     60.40        49
#
#     Cloudiness  Wind Speed Country        Date
# 0           98        2.24      TZ  1697084058
# 1          100       14.56      TF  1697084058
# 2          100        5.57      RU  1697083890
# 3           92       12.21      EC  1697083943
# 4          100        4.41      RU  1697083840
# 5            0        1.90      IN  1697083816
# 6           60       22.64      SH  1697083888
# 7          100       12.66      CK  1697084007
# 8           81       10.85      TK  1697084060
# 9           56        6.82      MM  1697084061
# 10          15        8.01      US  1697083375
# 11          71        3.13      NG  1697084061
# 12         100       15.01      RU  1697083816
# 13          28       10.00      RU  1697084062
# 14          96        5.70      AO  1697084062
# 15          89        8.21      CL  1697083901
# 16          20        6.91      CA  1697084063
# 17         100        4.00      ZA  1697084063
# 18          18       13.00      NZ  1697084064
# 19          21        3.13      NA  1697084064

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")
city_data_df = city_data_df.rename(columns={"Lat":"Latitude", "Lng":"Longitude", "Max Temp":"Max Temp (F)"})
# Display sample data
city_data_df.head()
# Out:
#                             City  Latitude  Longitude  Max Temp (F)  Humidity  \
# City_ID
# 0                         bukene   -4.2333    32.8833         70.52        69
# 1              port-aux-francais  -49.3500    70.2167         34.74       100
# 2                       bilibino   68.0546   166.4372         19.96        86
# 3        puerto baquerizo moreno   -0.9000   -89.6000         75.33        80
# 4                         mirnyy   62.5353   113.9611         41.67        96
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                98        2.24      TZ  1697084058
# 1               100       14.56      TF  1697084058
# 2               100        5.57      RU  1697083890
# 3                92       12.21      EC  1697083943
# 4               100        4.41      RU  1697083840

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

city_data_df.plot(kind="scatter", x="Latitude", y="Max Temp (F)", grid=True, title="City Latitude vs. Max. Temperature")

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Latitude", y="Humidity", grid=True, title="City Latitude vs. Humidity")


# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", x="Latitude", y="Cloudiness", grid=True, title="City Latitude vs. Cloud Coverage")


# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", x="Latitude", y="Wind Speed", grid=True, title="City Latitude vs. Wind Speed")

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
latitude = city_data_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(latitude, y_val)

regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Latitude"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City  Latitude  Longitude  Max Temp (F)  Humidity  Cloudiness  \
# City_ID
# 2           bilibino   68.0546   166.4372         19.96        86         100
# 4             mirnyy   62.5353   113.9611         41.67        96         100
# 5               tura   25.5198    90.2201         82.45        69           0
# 9            pathein   16.7833    94.7333         84.43        73          56
# 10       devils lake   48.1128   -98.8651         44.94        83          15
#
#          Wind Speed Country        Date
# City_ID
# 2              5.57      RU  1697083890
# 4              4.41      RU  1697083840
# 5              1.90      IN  1697083816
# 9              6.82      MM  1697084061
# 10             8.01      US  1697083375

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Latitude"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City  Latitude  Longitude  Max Temp (F)  \
# City_ID
# 0                             bukene   -4.2333    32.8833         70.52
# 1                  port-aux-francais  -49.3500    70.2167         34.74
# 3            puerto baquerizo moreno   -0.9000   -89.6000         75.33
# 6        edinburgh of the seven seas  -37.0676   -12.3116         56.44
# 7                             avarua  -21.2078  -159.7750         75.25
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0              69          98        2.24      TZ  1697084058
# 1             100         100       14.56      TF  1697084058
# 3              80          92       12.21      EC  1697083943
# 6              83          60       22.64      SH  1697083888
# 7              73         100       12.66      CK  1697084007

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Max Temp (F)"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title("Max. Temp vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_val = southern_hemi_df["Latitude"]
y_val = southern_hemi_df["Max Temp (F)"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (-30,280))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title("Max. Temp vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Humidity"]
y_val = northern_hemi_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Humidity vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Humidity"]
y_val = southern_hemi_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.title("Humidity vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Cloudiness"]
y_val = northern_hemi_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Cloudiness vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = northern_hemi_df["Cloudiness"]
y_val = northern_hemi_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Cloudiness vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Wind Speed"]
y_val = northern_hemi_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Wind Speed vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = northern_hemi_df["Wind Speed"]
y_val = northern_hemi_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Wind Speed")
plt.ylabel("Latitude")
plt.title("Wind Speed vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
