# Processing Record 4 of Set 5 | san carlos de bariloche
# Processing Record 5 of Set 5 | saint-philippe
# Processing Record 6 of Set 5 | natal
# Processing Record 7 of Set 5 | kargasok
# Processing Record 8 of Set 5 | lata
# Processing Record 9 of Set 5 | greymouth
# Processing Record 10 of Set 5 | marsh harbour
# Processing Record 11 of Set 5 | baise city
# Processing Record 12 of Set 5 | kristiansund
# Processing Record 13 of Set 5 | san luis de la loma
# Processing Record 14 of Set 5 | baotou
# Processing Record 15 of Set 5 | midvagur
# Processing Record 16 of Set 5 | salvador
# Processing Record 17 of Set 5 | kupang
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | port lincoln
# Processing Record 20 of Set 5 | aasiaat
# Processing Record 21 of Set 5 | grootfontein
# Processing Record 22 of Set 5 | dunedin
# Processing Record 23 of Set 5 | lompoc
# Processing Record 24 of Set 5 | mokhsogollokh
# Processing Record 25 of Set 5 | lihue
# Processing Record 26 of Set 5 | yabelo
# Processing Record 27 of Set 5 | sao vicente
# Processing Record 28 of Set 5 | nikolayevka
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | constantia
# Processing Record 31 of Set 5 | kuusamo
# Processing Record 32 of Set 5 | saarwellingen
# Processing Record 33 of Set 5 | moa
# Processing Record 34 of Set 5 | saudarkrokur
# Processing Record 35 of Set 5 | west island
# Processing Record 36 of Set 5 | kimbe
# Processing Record 37 of Set 5 | alofi
# Processing Record 38 of Set 5 | canton
# Processing Record 39 of Set 5 | howrah
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | mvomero
# Processing Record 42 of Set 5 | porto novo
# Processing Record 43 of Set 5 | ormara
# Processing Record 44 of Set 5 | palikir - national government center
# Processing Record 45 of Set 5 | carnarvon
# Processing Record 46 of Set 5 | tenenkou
# Processing Record 47 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 5 | tabou
# Processing Record 49 of Set 5 | balotra
# Processing Record 0 of Set 6 | hami
# Processing Record 1 of Set 6 | nantucket
# Processing Record 2 of Set 6 | chiras
# Processing Record 3 of Set 6 | ndungu
# Processing Record 4 of Set 6 | al fallujah
# Processing Record 5 of Set 6 | ghormach
# Processing Record 6 of Set 6 | kilju
# Processing Record 7 of Set 6 | sault ste. marie
# Processing Record 8 of Set 6 | ghanzi
# Processing Record 9 of Set 6 | bucerias
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | mili
# Processing Record 12 of Set 6 | port alfred
# Processing Record 13 of Set 6 | baikonur
# Processing Record 14 of Set 6 | bathsheba
# Processing Record 15 of Set 6 | tchintabaraden
# Processing Record 16 of Set 6 | konarka
# Processing Record 17 of Set 6 | queenstown
# Processing Record 18 of Set 6 | bodaybo
# Processing Record 19 of Set 6 | pitimbu
# Processing Record 20 of Set 6 | spring creek
# Processing Record 21 of Set 6 | ketchikan
# Processing Record 22 of Set 6 | afonso claudio
# Processing Record 23 of Set 6 | zhigalovo
# Processing Record 24 of Set 6 | khandyga
# Processing Record 25 of Set 6 | atafu village
# Processing Record 26 of Set 6 | igboho
# Processing Record 27 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 28 of Set 6 | ceelbuur
# Processing Record 29 of Set 6 | strathmore
# Processing Record 30 of Set 6 | bikenibeu village
# Processing Record 31 of Set 6 | bakanas
# Processing Record 32 of Set 6 | gallup
# Processing Record 33 of Set 6 | uchqurghon shahri
# Processing Record 34 of Set 6 | burley
# Processing Record 35 of Set 6 | nanao
# Processing Record 36 of Set 6 | alaior
# Processing Record 37 of Set 6 | al-`ula
# City not found. Skipping...
# Processing Record 38 of Set 6 | kurtamysh
# Processing Record 39 of Set 6 | lms
# City not found. Skipping...
# Processing Record 40 of Set 6 | puerto armuelles
# Processing Record 41 of Set 6 | borba
# Processing Record 42 of Set 6 | sao francisco
# Processing Record 43 of Set 6 | beau vallon
# Processing Record 44 of Set 6 | baker city
# Processing Record 45 of Set 6 | mount pearl
# Processing Record 46 of Set 6 | mejit
# Processing Record 47 of Set 6 | danjiangkou
# Processing Record 48 of Set 6 | pogar
# Processing Record 49 of Set 6 | rio grande
# Processing Record 0 of Set 7 | north fort myers
# Processing Record 1 of Set 7 | bure
# Processing Record 2 of Set 7 | kodinsk
# Processing Record 3 of Set 7 | ola
# Processing Record 4 of Set 7 | papao
# Processing Record 5 of Set 7 | teruel
# Processing Record 6 of Set 7 | balkanabat
# Processing Record 7 of Set 7 | anaconda
# Processing Record 8 of Set 7 | akureyri
# Processing Record 9 of Set 7 | winejok
# City not found. Skipping...
# Processing Record 10 of Set 7 | el tigre
# Processing Record 11 of Set 7 | extrema
# Processing Record 12 of Set 7 | north bend
# Processing Record 13 of Set 7 | hamilton
# Processing Record 14 of Set 7 | aljezur
# Processing Record 15 of Set 7 | puliyur
# Processing Record 16 of Set 7 | pacasmayo
# Processing Record 17 of Set 7 | carlsbad
# Processing Record 18 of Set 7 | vila franca do campo
# Processing Record 19 of Set 7 | fukuecho
# Processing Record 20 of Set 7 | verkhnevilyuysk
# Processing Record 21 of Set 7 | hadibu
# Processing Record 22 of Set 7 | minas de marcona
# Processing Record 23 of Set 7 | sanya
# Processing Record 24 of Set 7 | caleta de carquin
# Processing Record 25 of Set 7 | krasnoturansk
# Processing Record 26 of Set 7 | walvis bay
# Processing Record 27 of Set 7 | luanda
# Processing Record 28 of Set 7 | castillos
# Processing Record 29 of Set 7 | flying fish cove
# Processing Record 30 of Set 7 | tarko-sale
# Processing Record 31 of Set 7 | tlahualilo de zaragoza
# Processing Record 32 of Set 7 | parchim
# Processing Record 33 of Set 7 | belmonte
# Processing Record 34 of Set 7 | homer
# Processing Record 35 of Set 7 | fougamou
# Processing Record 36 of Set 7 | zhytkavichy
# Processing Record 37 of Set 7 | san clemente del tuyu
# Processing Record 6 of Set 9 | pangody
# Processing Record 7 of Set 9 | taoudenni
# Processing Record 8 of Set 9 | karratha
# Processing Record 9 of Set 9 | ma'rib
# Processing Record 10 of Set 9 | tazovsky
# Processing Record 11 of Set 9 | selfoss
# Processing Record 12 of Set 9 | st. john's
# Processing Record 13 of Set 9 | mogocha
# Processing Record 14 of Set 9 | watsa
# Processing Record 15 of Set 9 | corner brook
# Processing Record 16 of Set 9 | lerwick
# Processing Record 17 of Set 9 | maramba
# Processing Record 18 of Set 9 | gebeit
# Processing Record 19 of Set 9 | suva
# Processing Record 20 of Set 9 | mar del plata
# Processing Record 21 of Set 9 | chimoio
# Processing Record 22 of Set 9 | muisne
# Processing Record 23 of Set 9 | coahuayana de hidalgo
# Processing Record 24 of Set 9 | kaesong
# Processing Record 25 of Set 9 | karaton
# Processing Record 26 of Set 9 | college
# Processing Record 27 of Set 9 | cockburn town
# Processing Record 28 of Set 9 | kununurra
# Processing Record 29 of Set 9 | karasburg
# Processing Record 30 of Set 9 | biltine
# Processing Record 31 of Set 9 | sao jose da coroa grande
# Processing Record 32 of Set 9 | bonthe
# Processing Record 33 of Set 9 | umm kaddadah
# Processing Record 34 of Set 9 | afaahiti
# Processing Record 35 of Set 9 | whangarei
# Processing Record 36 of Set 9 | gradignan
# Processing Record 37 of Set 9 | sao miguel do iguacu
# Processing Record 38 of Set 9 | mao
# Processing Record 39 of Set 9 | kirensk
# Processing Record 40 of Set 9 | nahiyat ash shinafiyah
# Processing Record 41 of Set 9 | bamboo flat
# Processing Record 42 of Set 9 | patterson
# Processing Record 43 of Set 9 | manokwari
# Processing Record 44 of Set 9 | tsiombe
# Processing Record 45 of Set 9 | lobujya
# Processing Record 46 of Set 9 | ceeldheer
# Processing Record 47 of Set 9 | kapa'a
# Processing Record 48 of Set 9 | xinyu
# Processing Record 49 of Set 9 | tindouf
# Processing Record 0 of Set 10 | tehri
# Processing Record 1 of Set 10 | saint-francois
# Processing Record 2 of Set 10 | haiku-pauwela
# Processing Record 3 of Set 10 | trashi yangtse
# Processing Record 4 of Set 10 | tshikapa
# Processing Record 5 of Set 10 | thayetmyo
# Processing Record 6 of Set 10 | kone
# Processing Record 7 of Set 10 | palmas
# Processing Record 8 of Set 10 | xiva
# Processing Record 9 of Set 10 | lillesand
# Processing Record 10 of Set 10 | bairnsdale
# Processing Record 11 of Set 10 | kamien pomorski
# Processing Record 12 of Set 10 | valley city
# Processing Record 13 of Set 10 | torghay
# Processing Record 14 of Set 10 | mahibadhoo
# Processing Record 15 of Set 10 | akrehamn
# Processing Record 16 of Set 10 | alva
# Processing Record 17 of Set 10 | puerto ayacucho
# Processing Record 18 of Set 10 | yamada
# Processing Record 19 of Set 10 | gloucester
# Processing Record 20 of Set 10 | santa maria
# Processing Record 21 of Set 10 | miri
# Processing Record 22 of Set 10 | boende
# Processing Record 23 of Set 10 | pariaman
# Processing Record 24 of Set 10 | zhumysker
# Processing Record 25 of Set 10 | arthur's town
# City not found. Skipping...
# Processing Record 26 of Set 10 | piacabucu
# Processing Record 27 of Set 10 | ternate
# Processing Record 28 of Set 10 | sinan
# Processing Record 29 of Set 10 | hirara
# Processing Record 30 of Set 10 | cafayate
# Processing Record 31 of Set 10 | kalmunai
# Processing Record 32 of Set 10 | ongjin
# Processing Record 33 of Set 10 | el chorrillo
# Processing Record 34 of Set 10 | poplar bluff
# Processing Record 35 of Set 10 | jining
# Processing Record 36 of Set 10 | pokrovskoye
# Processing Record 37 of Set 10 | xining
# Processing Record 38 of Set 10 | dunay
# Processing Record 39 of Set 10 | al kharijah
# Processing Record 40 of Set 10 | ressano garcia
# Processing Record 41 of Set 10 | mega
# Processing Record 42 of Set 10 | petrozavodsk
# Processing Record 43 of Set 10 | jiazi
# Processing Record 44 of Set 10 | daru
# Processing Record 45 of Set 10 | kasimov
# Processing Record 46 of Set 10 | szecseny
# Processing Record 47 of Set 10 | clovis
# Processing Record 48 of Set 10 | petnjica
# Processing Record 49 of Set 10 | faranah
# Processing Record 0 of Set 11 | saynshand
# Processing Record 1 of Set 11 | ust'-ordynskiy
# Processing Record 2 of Set 11 | imbituba
# Processing Record 3 of Set 11 | broome
# Processing Record 4 of Set 11 | el daein
# City not found. Skipping...
# Processing Record 5 of Set 11 | sungai penuh
# Processing Record 6 of Set 11 | dalbandin
# Processing Record 7 of Set 11 | ulladulla
# Processing Record 8 of Set 11 | nhlangano
# Processing Record 9 of Set 11 | juan rodriguez clara
# Processing Record 10 of Set 11 | mugia
# Processing Record 11 of Set 11 | san antonio de pale
# Processing Record 12 of Set 11 | al ghayzah
# Processing Record 13 of Set 11 | igarka
# Processing Record 14 of Set 11 | kapsowar
# City not found. Skipping...
# Processing Record 15 of Set 11 | madan
# Processing Record 16 of Set 11 | sooke
# Processing Record 17 of Set 11 | saint-pierre
# Processing Record 18 of Set 11 | phumi veal sre
# Processing Record 19 of Set 11 | geraldton
# Processing Record 20 of Set 11 | praia
# Processing Record 21 of Set 11 | filadelfia
# Processing Record 22 of Set 11 | guapi
# Processing Record 23 of Set 11 | acarau
# Processing Record 24 of Set 11 | liezen
# Processing Record 25 of Set 11 | flin flon
# Processing Record 26 of Set 11 | kill devil hills
# Processing Record 27 of Set 11 | mengcheng chengguanzhen
# Processing Record 28 of Set 11 | vuktyl
# Processing Record 29 of Set 11 | kapoeta
# Processing Record 30 of Set 11 | leh
# Processing Record 31 of Set 11 | ndioum
# Processing Record 32 of Set 11 | charters towers
# Processing Record 33 of Set 11 | estancia
# Processing Record 34 of Set 11 | touros
# Processing Record 35 of Set 11 | vadso
# Processing Record 36 of Set 11 | tadine
# Processing Record 37 of Set 11 | happy valley-goose bay
# Processing Record 38 of Set 11 | suntar
# Processing Record 39 of Set 11 | ad dabbah
# Processing Record 40 of Set 11 | mpanda
# Processing Record 41 of Set 11 | west fargo
# Processing Record 42 of Set 11 | salsipuedes
# Processing Record 43 of Set 11 | jibia
# Processing Record 44 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 45 of Set 11 | lodja
# Processing Record 46 of Set 11 | mbanza-ngungu
# Processing Record 47 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 48 of Set 11 | ta'if
# Processing Record 49 of Set 11 | pizarro
# Processing Record 0 of Set 12 | elk
# Processing Record 1 of Set 12 | burang
# Processing Record 2 of Set 12 | fuglafjordur
# Processing Record 3 of Set 12 | eyl
# Processing Record 4 of Set 12 | buulobarde
# Processing Record 5 of Set 12 | yoko
# Processing Record 6 of Set 12 | barika
# Processing Record 7 of Set 12 | callao
# Processing Record 8 of Set 12 | acapulco de juarez
# Processing Record 9 of Set 12 | gonabad
# Processing Record 10 of Set 12 | eraan
# Processing Record 11 of Set 12 | soio
# Processing Record 12 of Set 12 | newport
# Processing Record 13 of Set 12 | riverside
# Processing Record 14 of Set 12 | ta`u
# Processing Record 15 of Set 12 | gidole
# Processing Record 16 of Set 12 | rikaze
# Processing Record 17 of Set 12 | och'amch'ire
# Processing Record 18 of Set 12 | tumayr
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | namibe
# Processing Record 21 of Set 12 | cidreira
# Processing Record 22 of Set 12 | amasra
# Processing Record 23 of Set 12 | oum hadjer
# Processing Record 24 of Set 12 | roccella ionica
# Processing Record 25 of Set 12 | galliano
# Processing Record 26 of Set 12 | puerto san jose
# Processing Record 27 of Set 12 | silver city
# Processing Record 28 of Set 12 | san andros
# City not found. Skipping...
# Processing Record 29 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 30 of Set 12 | crane
# Processing Record 31 of Set 12 | quirihue
# Processing Record 32 of Set 12 | tefe
# Processing Record 33 of Set 12 | krasnovishersk
# Processing Record 34 of Set 12 | bengkulu
# Processing Record 35 of Set 12 | lock haven
# Processing Record 36 of Set 12 | yeniseysk
# Processing Record 37 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 38 of Set 12 | chibougamau
# Processing Record 39 of Set 12 | novomikhaylovskiy
# Processing Record 40 of Set 12 | warrnambool
# Processing Record 41 of Set 12 | la jolla
# Processing Record 42 of Set 12 | santa terezinha
# Processing Record 43 of Set 12 | axim
# Processing Record 44 of Set 12 | calama
# Processing Record 45 of Set 12 | micheweni
# Processing Record 46 of Set 12 | dryden
# Processing Record 47 of Set 12 | ojinaga
# Processing Record 48 of Set 12 | jerome
# Processing Record 49 of Set 12 | corleone
# Processing Record 0 of Set 13 | sao joao da barra
# Processing Record 1 of Set 13 | jayapura
# Processing Record 2 of Set 13 | hengchun
# Processing Record 3 of Set 13 | allapalli
# Processing Record 4 of Set 13 | dawei
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

#Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
#Capitilizing city names 
city_data_df["City"]=city_data_df["City"].str.title()

# Display sample data
city_data_df.head(20)
# Out:
#                       City  Latitude  Longitude  Max Temp (F)  Humidity  \
# City_ID
# 0             Kudahuvadhoo    2.6708    72.8944         81.75        75
# 1        Port-Aux-Francais  -49.3500    70.2167         36.10        73
# 2                Jamestown   42.0970   -79.2353         48.02        87
# 3                  Grabouw  -34.1515    19.0151         59.40        90
# 4                 At-Bashi   41.1702    75.8106         40.71        64
# 5              Bayanhongor   46.7167   100.1167         26.80        34
# 6                   Uturoa  -16.7333  -151.4333         79.02        82
# 7            Blackmans Bay  -43.0167   147.3167         64.53        49
# 8                  Dudinka   69.4058    86.1778         31.68        98
# 9                   Kodiak   57.7900  -152.4072         47.71        87
# 10                Sinabang    2.4803    96.3801         78.24        85
# 11                Bilibino   68.0546   166.4372          4.96        96
# 12                   Kharp   66.8014    65.8081         34.99       100
# 13                 Talnakh   69.4865    88.3972         29.21        96
# 14                 Bubaque   11.2833   -15.8333         81.73        79
# 15                  Vanimo   -2.6741   141.3028         82.76        79
# 16                Waitangi  -43.9535  -176.5597         49.75        68
# 17                  Albany   42.6001   -73.9662         53.92        82
# 18                Saldanha  -33.0117    17.9442         59.05        92
# 19                   Yaren   -0.5472   166.9160         82.38        80
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                12        9.78      MV  1697587582
# 1                96       13.91      TF  1697587582
# 2               100        5.75      US  1697587245
# 3                10        5.41      ZA  1697587583
# 4                70        5.97      KG  1697587583
# 5                81        2.06      MN  1697587583
# 6                79       15.35      PF  1697587584
# 7                40        1.01      AU  1697587401
# 8               100        5.99      RU  1697587584
# 9               100       11.50      US  1697587585
# 10               99        6.85      ID  1697587585
# 11              100        3.51      RU  1697587585
# 12              100        3.47      RU  1697587585
# 13              100       16.98      RU  1697587586
# 14               38        8.61      GW  1697587586
# 15               58        4.16      PG  1697587587
# 16               43       14.61      NZ  1697587587
# 17               70        4.56      US  1697587347
# 18                2       11.72      ZA  1697587588
# 19              100       18.12      NR  1697587588

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")
city_data_df = city_data_df.rename(columns={"Lat":"Latitude", "Lng":"Longitude", "Max Temp":"Max Temp (F)"})

# Display sample data
city_data_df.head()
# Out:
#                       City  Latitude  Longitude  Max Temp (F)  Humidity  \
# City_ID
# 0             Kudahuvadhoo    2.6708    72.8944         81.75        75
# 1        Port-Aux-Francais  -49.3500    70.2167         36.10        73
# 2                Jamestown   42.0970   -79.2353         48.02        87
# 3                  Grabouw  -34.1515    19.0151         59.40        90
# 4                 At-Bashi   41.1702    75.8106         40.71        64
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                12        9.78      MV  1697587582
# 1                96       13.91      TF  1697587582
# 2               100        5.75      US  1697587245
# 3                10        5.41      ZA  1697587583
# 4                70        5.97      KG  1697587583

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Latitude", y="Max Temp (F)", grid=True, title="City Latitude vs. Max. Temperature")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Latitude", y="Humidity", grid=True, title="City Latitude vs. Humidity")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", x="Latitude", y="Cloudiness", grid=True, title="City Latitude vs. Cloud Coverage")


# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", x="Latitude", y="Wind Speed", grid=True, title="City Latitude vs. Wind Speed")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_val = city_data_df["Latitude"]
y_val = city_data_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Latitude"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City  Latitude  Longitude  Max Temp (F)  Humidity  \
# City_ID
# 0        Kudahuvadhoo    2.6708    72.8944         81.75        75
# 2           Jamestown   42.0970   -79.2353         48.02        87
# 4            At-Bashi   41.1702    75.8106         40.71        64
# 5         Bayanhongor   46.7167   100.1167         26.80        34
# 8             Dudinka   69.4058    86.1778         31.68        98
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                12        9.78      MV  1697587582
# 2               100        5.75      US  1697587245
# 4                70        5.97      KG  1697587583
# 5                81        2.06      MN  1697587583
# 8               100        5.99      RU  1697587584

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Latitude"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City  Latitude  Longitude  Max Temp (F)  Humidity  \
# City_ID
# 1        Port-Aux-Francais  -49.3500    70.2167         36.10        73
# 3                  Grabouw  -34.1515    19.0151         59.40        90
# 6                   Uturoa  -16.7333  -151.4333         79.02        82
# 7            Blackmans Bay  -43.0167   147.3167         64.53        49
# 15                  Vanimo   -2.6741   141.3028         82.76        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                96       13.91      TF  1697587582
# 3                10        5.41      ZA  1697587583
# 6                79       15.35      PF  1697587584
# 7                40        1.01      AU  1697587401
# 15               58        4.16      PG  1697587587

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Max Temp (F)"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title("Max. Temp vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_val = southern_hemi_df["Latitude"]
y_val = southern_hemi_df["Max Temp (F)"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (-30,280))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title("Max. Temp vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** In the two above scatterplot graphs showing Latitude vs. maximum temperature, we can see that there is a clear linear relationship in both the Northern Hemisphere and the Southern Hemisphere.  In the north, maximum temperature is directly, negatively correlated to latitude.  That is, the higher the latitude (the further north), the lower the maximum temperature will be.  We see this exact correlation mirrored in the Southern Hemisphere, where maximum temperature is positively correlated to latitude: the further south you go (lower latitudes), the lower the maximum temperature will be.  Of all the linear relationships depicted, this one has the strongest correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Latitude"]
y_val = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There is almost no correlation between humidity and latitude in either the Southern or the Northern Hemisphere.  We do see an overall higher rate of humidity in the Northern Hemispehre than the Southern Hemisphere, but from the above graphs we can see that humidity can occur in any latitude, and does not directly, strongly correlate to the latitude of that location.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Latitude"]
y_val = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** No linear relationship can be seen between latitude and cloudiness.  Of the three relationships graphed so far, this one has the smallest correlation.  What we can see on the scatterplot graphs is the strong tendency of locations to have either 0 or 100 cloudiness.  In both the Northern and the Southern Hemisphere, while there are many dots mid graph, there is a strong tendency towards the two extremes of the cloudiness spectrum.  This tendency is slightly stronger in the North than in the South.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Latitude"]
y_val = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** For wind speed versus latitude, there is a small positive correlation between latitude and windspeed in the Northern Hemisphere.  As altitude increases, so does wind speed. We also see more discrepancy between wind speeds at the higher latitudes.  That means that the further north we go, the windier it may be.  We see the opposite mirror correlation in the Southern Hemisphere.  The larger the latitude gets, which means the closer towards the equator, the lower the wind speed gets.  On both sides of the planet, we see wind speeds increasing towards the poles and decreasing towards the equator.
