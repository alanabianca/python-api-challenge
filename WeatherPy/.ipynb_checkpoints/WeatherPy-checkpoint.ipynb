# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 625

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city + "&appid=" + weather_api_key + "&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavaratti
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | kidal
# Processing Record 5 of Set 1 | karbala
# Processing Record 6 of Set 1 | bodaybo
# Processing Record 7 of Set 1 | hafar al-batin
# Processing Record 8 of Set 1 | college
# Processing Record 9 of Set 1 | harper
# Processing Record 10 of Set 1 | gustavia
# Processing Record 11 of Set 1 | ulladulla
# Processing Record 12 of Set 1 | adamstown
# Processing Record 13 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | rokycany
# Processing Record 16 of Set 1 | chonchi
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | lewistown
# Processing Record 19 of Set 1 | sitka
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | nishinoomote
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | hamilton
# Processing Record 26 of Set 1 | tazovsky
# Processing Record 27 of Set 1 | ploudalmezeau
# Processing Record 28 of Set 1 | yuanping
# Processing Record 29 of Set 1 | sudogda
# Processing Record 30 of Set 1 | utrik
# Processing Record 31 of Set 1 | whitehorse
# Processing Record 32 of Set 1 | puerto natales
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | port-aux-francais
# Processing Record 35 of Set 1 | bargara
# City not found. Skipping...
# Processing Record 36 of Set 1 | port saint john's
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | serenje
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | soe
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | bac lieu
# Processing Record 43 of Set 1 | west island
# Processing Record 44 of Set 1 | stanley
# Processing Record 45 of Set 1 | al muwayh
# Processing Record 46 of Set 1 | tomatlan
# Processing Record 47 of Set 1 | ulaangom
# Processing Record 48 of Set 1 | badger
# Processing Record 49 of Set 1 | polyarnyy
# Processing Record 50 of Set 1 | vorgashor
# Processing Record 0 of Set 2 | east london
# Processing Record 1 of Set 2 | mount gambier
# Processing Record 2 of Set 2 | valjevo
# Processing Record 3 of Set 2 | sakakah
# Processing Record 4 of Set 2 | port mathurin
# Processing Record 5 of Set 2 | chemax
# Processing Record 6 of Set 2 | fortaleza
# Processing Record 7 of Set 2 | kangding
# Processing Record 8 of Set 2 | usinsk
# Processing Record 9 of Set 2 | turpan
# Processing Record 10 of Set 2 | pacific grove
# Processing Record 11 of Set 2 | djamaa
# Processing Record 12 of Set 2 | happy valley-goose bay
# Processing Record 13 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 14 of Set 2 | ust-nera
# Processing Record 15 of Set 2 | cafayate
# Processing Record 16 of Set 2 | tolanaro
# Processing Record 17 of Set 2 | pacocha
# Processing Record 5 of Set 5 | karangampel
# Processing Record 6 of Set 5 | oltinko'l
# Processing Record 7 of Set 5 | ballina
# Processing Record 8 of Set 5 | ta`u
# Processing Record 9 of Set 5 | tadine
# Processing Record 10 of Set 5 | isafjordur
# Processing Record 11 of Set 5 | hadibu
# Processing Record 12 of Set 5 | yulinshi
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | champerico
# Processing Record 15 of Set 5 | alaghsas
# Processing Record 16 of Set 5 | la'ie
# Processing Record 17 of Set 5 | bayganin
# Processing Record 18 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 5 | rybinsk
# Processing Record 20 of Set 5 | qaqortoq
# Processing Record 21 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 22 of Set 5 | nyurba
# Processing Record 23 of Set 5 | priargunsk
# Processing Record 24 of Set 5 | pundong
# Processing Record 25 of Set 5 | ntungamo
# Processing Record 26 of Set 5 | howrah
# Processing Record 27 of Set 5 | brokopondo
# Processing Record 28 of Set 5 | mitu
# Processing Record 29 of Set 5 | abepura
# Processing Record 30 of Set 5 | wakkanai
# Processing Record 31 of Set 5 | nova sintra
# Processing Record 32 of Set 5 | yoichi
# Processing Record 33 of Set 5 | laela
# Processing Record 34 of Set 5 | matoury
# Processing Record 35 of Set 5 | tvoroyri
# Processing Record 36 of Set 5 | vila franca do campo
# Processing Record 37 of Set 5 | melo
# Processing Record 38 of Set 5 | bela
# Processing Record 39 of Set 5 | labrador city
# Processing Record 40 of Set 5 | afaahiti
# Processing Record 41 of Set 5 | sinan
# Processing Record 42 of Set 5 | zhalantun
# Processing Record 43 of Set 5 | praia da vitoria
# Processing Record 44 of Set 5 | luderitz
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | tazacorte
# Processing Record 47 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 48 of Set 5 | ustyuzhna
# Processing Record 49 of Set 5 | saipan
# Processing Record 0 of Set 6 | jasper
# Processing Record 1 of Set 6 | bikenibeu village
# Processing Record 2 of Set 6 | kralendijk
# Processing Record 3 of Set 6 | gadzhiyevo
# Processing Record 4 of Set 6 | prado
# Processing Record 5 of Set 6 | midvagur
# Processing Record 6 of Set 6 | okhotsk
# Processing Record 7 of Set 6 | geneina
# Processing Record 8 of Set 6 | tillaberi
# Processing Record 9 of Set 6 | dano
# Processing Record 10 of Set 6 | metlili chaamba
# Processing Record 11 of Set 6 | vadso
# Processing Record 12 of Set 6 | qamdo
# Processing Record 13 of Set 6 | lepsy
# Processing Record 14 of Set 6 | grande prairie
# Processing Record 15 of Set 6 | chinchani
# Processing Record 16 of Set 6 | palikir - national government center
# Processing Record 17 of Set 6 | colinas
# Processing Record 18 of Set 6 | srivardhan
# Processing Record 19 of Set 6 | shiprock
# Processing Record 20 of Set 6 | sisimiut
# Processing Record 21 of Set 6 | melfi
# Processing Record 22 of Set 6 | ushtobe
# Processing Record 23 of Set 6 | ginir
# Processing Record 24 of Set 6 | kalmunai
# Processing Record 25 of Set 6 | weno
# Processing Record 26 of Set 6 | vila velha
# Processing Record 27 of Set 6 | fisterra
# Processing Record 28 of Set 6 | richards bay
# Processing Record 29 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 30 of Set 6 | fort st. john
# Processing Record 31 of Set 6 | skelleftea
# Processing Record 32 of Set 6 | el rama
# Processing Record 33 of Set 6 | argostolion
# Processing Record 34 of Set 6 | el daein
# City not found. Skipping...
# Processing Record 35 of Set 6 | hobyo
# Processing Record 36 of Set 6 | tsetserleg
# Processing Record 37 of Set 6 | kingscliff
# Processing Record 38 of Set 6 | keflavik
# Processing Record 39 of Set 6 | iquitos
# Processing Record 40 of Set 6 | nemuro
# Processing Record 41 of Set 6 | pergamino
# Processing Record 42 of Set 6 | am timan
# Processing Record 43 of Set 6 | zhigalovo
# Processing Record 44 of Set 6 | ijuw
# City not found. Skipping...
# Processing Record 45 of Set 6 | kapuskasing
# Processing Record 46 of Set 6 | waingapu
# Processing Record 47 of Set 6 | arcoverde
# Processing Record 48 of Set 6 | new norfolk
# Processing Record 49 of Set 6 | tual
# Processing Record 0 of Set 7 | taoudenni
# Processing Record 1 of Set 7 | cabugao
# Processing Record 2 of Set 7 | mandera
# Processing Record 3 of Set 7 | palembang
# Processing Record 4 of Set 7 | yuzhno-kurilsk
# Processing Record 5 of Set 7 | toliara
# Processing Record 6 of Set 7 | xiangxiang
# Processing Record 7 of Set 7 | arno
# Processing Record 8 of Set 7 | iskateley
# Processing Record 9 of Set 7 | karasburg
# Processing Record 10 of Set 7 | faya-largeau
# Processing Record 11 of Set 7 | anna regina
# Processing Record 12 of Set 7 | blagodarnyy
# Processing Record 13 of Set 7 | naze
# Processing Record 14 of Set 7 | callao
# Processing Record 15 of Set 7 | xixiang
# Processing Record 16 of Set 7 | salina cruz
# Processing Record 17 of Set 7 | wainwright
# Processing Record 18 of Set 7 | polewali
# Processing Record 19 of Set 7 | villarrica
# Processing Record 20 of Set 7 | huanggang
# Processing Record 21 of Set 7 | san juan
# Processing Record 22 of Set 7 | port hedland
# Processing Record 23 of Set 7 | lautoka
# Processing Record 24 of Set 7 | fayroz koh
# Processing Record 25 of Set 7 | sinop
# Processing Record 26 of Set 7 | alvaraes
# Processing Record 27 of Set 7 | ugoofaaru
# Processing Record 28 of Set 7 | xining
# Processing Record 29 of Set 7 | del rio
# Processing Record 30 of Set 7 | vilyuchinsk
# Processing Record 31 of Set 7 | tenenkou
# Processing Record 32 of Set 7 | kuqa
# Processing Record 33 of Set 7 | tamale
# Processing Record 34 of Set 7 | yinchuan
# Processing Record 35 of Set 7 | shihezi
# Processing Record 36 of Set 7 | okha
# Processing Record 37 of Set 7 | ghanzi
# Processing Record 38 of Set 7 | drayton valley
# Processing Record 39 of Set 7 | ancud
# Processing Record 40 of Set 7 | ad dilam
# Processing Record 41 of Set 7 | bulolo
# Processing Record 11 of Set 9 | bredasdorp
# Processing Record 12 of Set 9 | fort bragg
# Processing Record 13 of Set 9 | kone
# Processing Record 14 of Set 9 | lerwick
# Processing Record 15 of Set 9 | manokwari
# Processing Record 16 of Set 9 | nelson bay
# Processing Record 17 of Set 9 | brookings
# Processing Record 18 of Set 9 | syzran'
# Processing Record 19 of Set 9 | shizunai-furukawacho
# Processing Record 20 of Set 9 | auki
# Processing Record 21 of Set 9 | kingston
# Processing Record 22 of Set 9 | aginskoye
# Processing Record 23 of Set 9 | puerto aysen
# Processing Record 24 of Set 9 | madera
# Processing Record 25 of Set 9 | kirensk
# Processing Record 26 of Set 9 | gutao
# Processing Record 27 of Set 9 | nguruka
# Processing Record 28 of Set 9 | shido
# Processing Record 29 of Set 9 | lahad datu
# Processing Record 30 of Set 9 | al ajaylat
# City not found. Skipping...
# Processing Record 31 of Set 9 | saldanha
# Processing Record 32 of Set 9 | jinja
# Processing Record 33 of Set 9 | sao tome
# Processing Record 34 of Set 9 | klyuchi
# Processing Record 35 of Set 9 | grand-popo
# Processing Record 36 of Set 9 | bhimbar
# Processing Record 37 of Set 9 | uige
# Processing Record 38 of Set 9 | yengema
# Processing Record 39 of Set 9 | puerto deseado
# Processing Record 40 of Set 9 | kargasok
# Processing Record 41 of Set 9 | ust'-kulom
# Processing Record 42 of Set 9 | salavan
# Processing Record 43 of Set 9 | terekeka
# City not found. Skipping...
# Processing Record 44 of Set 9 | flying fish cove
# Processing Record 45 of Set 9 | casper
# Processing Record 46 of Set 9 | lodwar
# Processing Record 47 of Set 9 | lima
# Processing Record 48 of Set 9 | diego martin
# Processing Record 49 of Set 9 | micheweni
# Processing Record 0 of Set 10 | waldshut-tiengen
# Processing Record 1 of Set 10 | mogocha
# Processing Record 2 of Set 10 | amahai
# Processing Record 3 of Set 10 | portland
# Processing Record 4 of Set 10 | bloomsburg
# Processing Record 5 of Set 10 | oranjemund
# Processing Record 6 of Set 10 | nambucca heads
# Processing Record 7 of Set 10 | sokhumi
# Processing Record 8 of Set 10 | tongouson
# Processing Record 9 of Set 10 | san ignacio de velasco
# Processing Record 10 of Set 10 | peace river
# Processing Record 11 of Set 10 | pimentel
# Processing Record 12 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 13 of Set 10 | weinan
# Processing Record 14 of Set 10 | carrizal
# Processing Record 15 of Set 10 | taiyuan
# Processing Record 16 of Set 10 | queenstown
# Processing Record 17 of Set 10 | tekirdag
# Processing Record 18 of Set 10 | westport
# Processing Record 19 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 20 of Set 10 | dalandzadgad
# Processing Record 21 of Set 10 | kurumkan
# Processing Record 22 of Set 10 | guarapari
# Processing Record 23 of Set 10 | novo aripuana
# Processing Record 24 of Set 10 | baihe
# Processing Record 25 of Set 10 | manadhoo
# Processing Record 26 of Set 10 | guanica
# Processing Record 27 of Set 10 | mukalla
# Processing Record 28 of Set 10 | enid
# Processing Record 29 of Set 10 | claveria
# Processing Record 30 of Set 10 | miguelopolis
# Processing Record 31 of Set 10 | tanjung selor
# City not found. Skipping...
# Processing Record 32 of Set 10 | thongwa
# Processing Record 33 of Set 10 | coracora
# Processing Record 34 of Set 10 | carrboro
# Processing Record 35 of Set 10 | urzhar
# Processing Record 36 of Set 10 | vila do maio
# Processing Record 37 of Set 10 | port hueneme
# Processing Record 38 of Set 10 | la gi
# Processing Record 39 of Set 10 | celestun
# Processing Record 40 of Set 10 | maiurno
# Processing Record 41 of Set 10 | coquimbo
# Processing Record 42 of Set 10 | chirpan
# Processing Record 43 of Set 10 | dudinka
# Processing Record 44 of Set 10 | badin
# Processing Record 45 of Set 10 | praya
# Processing Record 46 of Set 10 | howard springs
# Processing Record 47 of Set 10 | leh
# Processing Record 48 of Set 10 | mandimba
# City not found. Skipping...
# Processing Record 49 of Set 10 | eydhafushi
# Processing Record 0 of Set 11 | qulsary
# Processing Record 1 of Set 11 | demmin
# Processing Record 2 of Set 11 | masvingo
# Processing Record 3 of Set 11 | pangody
# Processing Record 4 of Set 11 | grand rapids
# Processing Record 5 of Set 11 | puerto lempira
# Processing Record 6 of Set 11 | juybar
# Processing Record 7 of Set 11 | kruisfontein
# Processing Record 8 of Set 11 | reggane
# Processing Record 9 of Set 11 | pimpri
# Processing Record 10 of Set 11 | mbeni
# Processing Record 11 of Set 11 | barstow
# Processing Record 12 of Set 11 | suva
# Processing Record 13 of Set 11 | vanimo
# Processing Record 14 of Set 11 | ortona
# Processing Record 15 of Set 11 | pemangkat
# Processing Record 16 of Set 11 | birao
# Processing Record 17 of Set 11 | pandan
# Processing Record 18 of Set 11 | saint-philippe
# Processing Record 19 of Set 11 | brisas de zicatela
# Processing Record 20 of Set 11 | ondjiva
# Processing Record 21 of Set 11 | piui
# Processing Record 22 of Set 11 | puerto ayacucho
# Processing Record 23 of Set 11 | fale old settlement
# Processing Record 24 of Set 11 | awjilah
# Processing Record 25 of Set 11 | noyabrsk
# Processing Record 26 of Set 11 | axim
# Processing Record 27 of Set 11 | kiiminki
# Processing Record 28 of Set 11 | titagarh
# Processing Record 29 of Set 11 | bakchar
# Processing Record 30 of Set 11 | mugia
# Processing Record 31 of Set 11 | kurtamysh
# Processing Record 32 of Set 11 | sanming
# Processing Record 33 of Set 11 | sola
# Processing Record 34 of Set 11 | gamba
# Processing Record 35 of Set 11 | lardero
# Processing Record 36 of Set 11 | tarawa
# Processing Record 37 of Set 11 | sao felix do xingu
# Processing Record 38 of Set 11 | poronaysk
# Processing Record 39 of Set 11 | necochea
# Processing Record 40 of Set 11 | ghatampur
# Processing Record 41 of Set 11 | calolbon
# Processing Record 42 of Set 11 | mendoza
# Processing Record 43 of Set 11 | cheremukhovo
# Processing Record 44 of Set 11 | nazare
# Processing Record 45 of Set 11 | damongo
# City not found. Skipping...
# Processing Record 46 of Set 11 | nouadhibou
# Processing Record 47 of Set 11 | qarqin
# Processing Record 48 of Set 11 | pocora
# Processing Record 49 of Set 11 | jean-rabel
# Processing Record 0 of Set 12 | kuta
# Processing Record 1 of Set 12 | palmer
# Processing Record 2 of Set 12 | mohr
# Processing Record 3 of Set 12 | madalena
# Processing Record 4 of Set 12 | north side
# Processing Record 5 of Set 12 | saltillo
# Processing Record 6 of Set 12 | eldorado
# Processing Record 7 of Set 12 | zouerate
# Processing Record 8 of Set 12 | tumut
# Processing Record 9 of Set 12 | xuanzhou
# Processing Record 10 of Set 12 | sabang
# Processing Record 11 of Set 12 | banda aceh
# Processing Record 12 of Set 12 | rosetta
# Processing Record 13 of Set 12 | mil'kovo
# Processing Record 14 of Set 12 | kayangel
# Processing Record 15 of Set 12 | chivhu
# Processing Record 16 of Set 12 | quellon
# Processing Record 17 of Set 12 | redding
# Processing Record 18 of Set 12 | lucerne valley
# Processing Record 19 of Set 12 | thinadhoo
# Processing Record 20 of Set 12 | kenora
# Processing Record 21 of Set 12 | nuuk
# Processing Record 22 of Set 12 | oamaru
# Processing Record 23 of Set 12 | an nuhud
# Processing Record 24 of Set 12 | bethanie
# Processing Record 25 of Set 12 | al qadarif
# Processing Record 26 of Set 12 | muisne
# Processing Record 27 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 28 of Set 12 | berezovyy
# Processing Record 29 of Set 12 | jaguaruna
# Processing Record 30 of Set 12 | coahuayana de hidalgo
# Processing Record 31 of Set 12 | poyarkovo
# Processing Record 32 of Set 12 | wanning
# Processing Record 33 of Set 12 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 12 | pudozh
# Processing Record 35 of Set 12 | skvyra
# Processing Record 36 of Set 12 | isola di capo rizzuto
# Processing Record 37 of Set 12 | devgarh
# Processing Record 38 of Set 12 | san francisco
# Processing Record 39 of Set 12 | kitgum
# Processing Record 40 of Set 12 | cockburn town
# Processing Record 41 of Set 12 | karatuzskoye
# Processing Record 42 of Set 12 | nogliki
# Processing Record 43 of Set 12 | sao joao da barra
# Processing Record 44 of Set 12 | ad dabbah
# Processing Record 45 of Set 12 | port dickson
# Processing Record 46 of Set 12 | barcelos
# Processing Record 47 of Set 12 | martaban
# Processing Record 48 of Set 12 | dingcheng
# Processing Record 49 of Set 12 | maamba
# Processing Record 0 of Set 13 | mahibadhoo
# Processing Record 1 of Set 13 | princeville
# Processing Record 2 of Set 13 | santa vitoria do palmar
# Processing Record 3 of Set 13 | plettenberg bay
# Processing Record 4 of Set 13 | port augusta
# Processing Record 5 of Set 13 | inarajan village
# Processing Record 6 of Set 13 | akureyri
# Processing Record 7 of Set 13 | maputo
# Processing Record 8 of Set 13 | peacehaven
# Processing Record 9 of Set 13 | kuching
# Processing Record 10 of Set 13 | fortuna
# Processing Record 11 of Set 13 | el sauzal de rodriguez
# Processing Record 12 of Set 13 | aykhal
# Processing Record 13 of Set 13 | puerto colombia
# Processing Record 14 of Set 13 | mstsislaw
# Processing Record 15 of Set 13 | revda
# Processing Record 16 of Set 13 | xichang
# Processing Record 17 of Set 13 | cidade velha
# Processing Record 18 of Set 13 | viana do castelo
# Processing Record 19 of Set 13 | santa maria
# Processing Record 20 of Set 13 | kaa-khem
# Processing Record 21 of Set 13 | tobi village
# City not found. Skipping...
# Processing Record 22 of Set 13 | lagdo
# Processing Record 23 of Set 13 | kogalym
# Processing Record 24 of Set 13 | santa cruz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df["City"]=city_data_df["City"].str.title()

#Show Record Count
city_data_df.count()
# Out:
# City          598
# Lat           598
# Lng           598
# Max Temp      598
# Humidity      598
# Cloudiness    598
# Wind Speed    598
# Country       598
# Date          598
# dtype: int64

# %%
#Capitilizing city names 
city_data_df["City"]=city_data_df["City"].str.title()

# Display sample data
city_data_df.head(20)
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# 0                     Kavaratti  10.5669   72.6420     81.90        71
# 1                  Longyearbyen  78.2186   15.6401     31.84        59
# 2   Edinburgh Of The Seven Seas -37.0676  -12.3116     53.62        76
# 3                         Kidal  18.4411    1.4078     85.62        13
# 4                       Karbala  32.6160   44.0249     78.17        35
# 5                       Bodaybo  57.8506  114.1933     34.43        84
# 6                Hafar Al-Batin  28.4328   45.9708     81.18        26
# 7                       College  64.8569 -147.8028     38.44        89
# 8                        Harper   4.3750   -7.7169     76.80        90
# 9                      Gustavia  17.8962  -62.8498     83.79        76
# 10                    Ulladulla -35.3500  150.4667     64.76        47
# 11                    Adamstown -25.0660 -130.1015     71.67        80
# 12                     Waitangi -43.9535 -176.5597     54.82        75
# 13                     Rokycany  49.7427   13.5946     39.09        95
# 14                      Chonchi -42.6128  -73.8092     51.12        91
# 15                         Lebu -37.6167  -73.6500     50.31        69
# 16                    Lewistown  40.5992  -77.5714     53.01        82
# 17                        Sitka  57.0531 -135.3300     55.29        82
# 18                    Grytviken -54.2811  -36.5092     33.30        89
# 19               Ribeira Grande  38.5167  -28.7000     71.78        91
#
#     Cloudiness  Wind Speed Country        Date
# 0           78        5.57      IN  1697410382
# 1           75       17.27      SJ  1697410290
# 2           83       27.65      SH  1697410382
# 3           43        2.53      ML  1697410383
# 4            1       10.67      IQ  1697410383
# 5          100        3.00      RU  1697410179
# 6            0        6.91      SA  1697410383
# 7           75        5.75      US  1697410384
# 8          100        8.30      LR  1697410384
# 9           26        4.00      BL  1697410384
# 10          75       11.45      AU  1697410385
# 11          64        9.04      PN  1697410385
# 12          21       11.01      NZ  1697410386
# 13          19       14.00      CZ  1697410386
# 14          78        2.19      CL  1697410097
# 15           2       19.28      CL  1697410386
# 16          75        4.61      US  1697410352
# 17         100        5.75      US  1697410387
# 18          81       11.12      GS  1697410387
# 19         100       25.99      PT  1697410388

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")
city_data_df = city_data_df.rename(columns={"Lat":"Latitude", "Lng":"Longitude", "Max Temp":"Max Temp (F)"})
# Display sample data
city_data_df.head()
# Out:
#                                 City  Latitude  Longitude  Max Temp (F)  \
# City_ID
# 0                          Kavaratti   10.5669    72.6420         81.90
# 1                       Longyearbyen   78.2186    15.6401         31.84
# 2        Edinburgh Of The Seven Seas  -37.0676   -12.3116         53.62
# 3                              Kidal   18.4411     1.4078         85.62
# 4                            Karbala   32.6160    44.0249         78.17
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0              71          78        5.57      IN  1697410382
# 1              59          75       17.27      SJ  1697410290
# 2              76          83       27.65      SH  1697410382
# 3              13          43        2.53      ML  1697410383
# 4              35           1       10.67      IQ  1697410383

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

city_data_df.plot(kind="scatter", x="Latitude", y="Max Temp (F)", grid=True, title="City Latitude vs. Max. Temperature")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Latitude", y="Humidity", grid=True, title="City Latitude vs. Humidity")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", x="Latitude", y="Cloudiness", grid=True, title="City Latitude vs. Cloud Coverage")



# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", x="Latitude", y="Wind Speed", grid=True, title="City Latitude vs. Wind Speed")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
latitude = city_data_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(latitude, y_val)

regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Latitude"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City  Latitude  Longitude  Max Temp (F)  Humidity  \
# City_ID
# 0           Kavaratti   10.5669    72.6420         81.90        71
# 1        Longyearbyen   78.2186    15.6401         31.84        59
# 3               Kidal   18.4411     1.4078         85.62        13
# 4             Karbala   32.6160    44.0249         78.17        35
# 5             Bodaybo   57.8506   114.1933         34.43        84
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                78        5.57      IN  1697410382
# 1                75       17.27      SJ  1697410290
# 3                43        2.53      ML  1697410383
# 4                 1       10.67      IQ  1697410383
# 5               100        3.00      RU  1697410179

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Latitude"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City  Latitude  Longitude  Max Temp (F)  \
# City_ID
# 2        Edinburgh Of The Seven Seas  -37.0676   -12.3116         53.62
# 10                         Ulladulla  -35.3500   150.4667         64.76
# 11                         Adamstown  -25.0660  -130.1015         71.67
# 12                          Waitangi  -43.9535  -176.5597         54.82
# 14                           Chonchi  -42.6128   -73.8092         51.12
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 2              76          83       27.65      SH  1697410382
# 10             47          75       11.45      AU  1697410385
# 11             80          64        9.04      PN  1697410385
# 12             75          21       11.01      NZ  1697410386
# 14             91          78        2.19      CL  1697410097

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Max Temp (F)"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title("Max. Temp vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_val = southern_hemi_df["Latitude"]
y_val = southern_hemi_df["Max Temp (F)"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (-30,280))
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.title("Max. Temp vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** In the two above scatterplot graphs showing Latitude vs. maximum temperature, we can see that there is a clear linear relationship in both the Northern Hemisphere and the Southern Hemisphere.  In the north, maximum temperature is directly, negatively correlated to latitude.  That is, the higher the latitude (the further north), the lower the maximum temperature will be.  We see this exact correlation mirrored in the Southern Hemisphere, where maximum temperature is positively correlated to latitude: the further south you go (higher latitudes), the lower the maximum temperature will be.  Of all the linear relationships depicted, this one has the strongest correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Latitude"]
y_val = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There is almost no correlation between humidity and latitude in either the Southern or the Northern Hemisphere.  We do see an overall higher rate of humidity in the Northern Hemispehre than the Southern Hemisphere, but from the above graphs we can see that humidity can occur in any latitude, and does not directly, strongly correlate to the latitude of that location.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = northern_hemi_df["Cloudiness"]
y_val = northern_hemi_df["Latitude"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.title("Cloudiness vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs. Latitude: Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
x_val = northern_hemi_df["Latitude"]
y_val = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr)=linregress(x_val, y_val)

regress_values = x_val * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_val, y_val)
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq, (40,300))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed vs. Latitude: Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
